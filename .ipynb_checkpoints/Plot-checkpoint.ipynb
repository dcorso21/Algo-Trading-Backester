# %%
import plotly
plotly.offline.init_notebook_mode(connected=True)
plotly.offline.iplot

from local_functions.plotting import plot_results as plotr
from local_functions.pull_historical import historical_funcs as hist
m = hist.get_mkt_data('example.csv')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-0b11aff1c6de> in <module>
#       3 plotly.offline.iplot
#       4
# ----> 5 from local_functions.plotting import plot_results as plotr
#       6 from local_functions.pull_historical import historical_funcs as hist
#       7 m = hist.get_mkt_data('example.csv')
#
# ~\Documents\Python\Algorithmic Trading\local_functions\plotting\plot_results.py in <module>
#       1 import pandas as pd
#       2 import plotly.graph_objects as go
# ----> 3 from local_functions.pull_historical import historical_funcs as hist
#       4
#       5
#
# ~\Documents\Python\Algorithmic Trading\local_functions\pull_historical\historical_funcs.py in <module>
# ----> 1 from local_functions.main import global_vars as gl
#       2
#       3
#       4 def create_second_data(index, mode='mixed'):
#       5
#
# ~\Documents\Python\Algorithmic Trading\local_functions\main\global_vars.py in <module>
#      43 # Sim Data
#      44 # only need to reference this once.
# ---> 45 sim_df = hist.get_mkt_data(r'example.csv')
#      46
#      47 # All assets start as blank.
#
# AttributeError: module 'local_functions.pull_historical.historical_funcs' has no attribute 'get_mkt_data'

# %%
plotr.plot_results(m)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6bb5319e691e> in <module>
# ----> 1 plotr.plot_results(m)
#
# NameError: name 'plotr' is not defined

# %%
plotr.plot_momentum()
