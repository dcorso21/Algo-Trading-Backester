# %%
import plotly
plotly.offline.init_notebook_mode(connected=True)
plotly.offline.iplot

from local_functions.plotting import plot_results as plotr
from local_functions.pull_historical import historical_funcs as hist
m = hist.get_mkt_data('example.csv')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
plotr.plot_results(m)

# %%
plotr.plot_momentum()

# %%
from local_functions.main import algo

algo.main_algo()
# Out:
# files reset
# current minute : 11:05:00
# done
